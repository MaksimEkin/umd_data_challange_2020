# %%
# Import necessary Python, sklearn and/or tensorflow/keras modules for loading the dataset
import os
import pandas as pd
import numpy as np


#Load the data
DATA_FILE = 'Data_Level5_BAH_OceanCleanup.csv'
if not os.path.exists(DATA_FILE):
    raise Exception('Data file not found. Make sure that the file is located in the same directory as the notebook')

df = pd.read_csv(DATA_FILE, sep=',', header=0, index_col=False)

# Basic overview of data shape, size, and type
df.info()

# Print data shape via built-in methods of sklearn, pandas or tensorflow/keras (or other modules)
print('\nDataframe shape: ', df.shape)

df.iloc[df['Miles'].argmax()]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37904 entries, 0 to 37903
# Data columns (total 61 columns):
# Cleanup ID                                   37904 non-null object
# Zone                                         37665 non-null object
# State                                        37577 non-null object
# Country                                      37903 non-null object
# GPS                                          37903 non-null object
# Cleanup Type                                 37903 non-null object
# Cleanup Date                                 37903 non-null object
# Group Name                                   26636 non-null object
# Adults                                       37903 non-null float64
# Children                                     37903 non-null float64
# People                                       37903 non-null float64
# Pounds                                       37903 non-null float64
# Miles                                        37903 non-null float64
# # of bags                                    37903 non-null float64
# Cigarette Butts                              37904 non-null int64
# Food Wrappers (candy, chips, etc.)           37904 non-null int64
# Take Out/Away Containers (Plastic)           37904 non-null int64
# Take Out/Away Containers (Foam)              37904 non-null int64
# Bottle Caps (Plastic)                        37904 non-null int64
# Bottle Caps (Metal)                          37904 non-null int64
# Lids (Plastic)                               37904 non-null int64
# Straws, Stirrers                             37904 non-null int64
# Forks, Knives, Spoons                        37904 non-null int64
# Beverage Bottles (Plastic)                   37904 non-null int64
# Beverage Bottles (Glass)                     37904 non-null int64
# Beverage Cans                                37904 non-null int64
# Grocery Bags (Plastic)                       37904 non-null int64
# Other Plastic Bags                           37904 non-null int64
# Paper Bags                                   37904 non-null int64
# Cups, Plates (Paper)                         37904 non-null int64
# Cups, Plates (Plastic)                       37904 non-null int64
# Cups, Plates (Foam)                          37904 non-null int64
# Fishing Buoys, Pots & Traps                  37904 non-null int64
# Fishing Net & Pieces                         37904 non-null int64
# Fishing Line (1 yard/meter = 1 piece)        37904 non-null int64
# Rope (1 yard/meter = 1 piece)                37904 non-null int64
# Fishing Gear (Clean Swell)                   37904 non-null int64
# 6-Pack Holders                               37904 non-null int64
# Other Plastic/Foam Packaging                 37904 non-null int64
# Other Plastic Bottles (oil, bleach, etc.)    37904 non-null int64
# Strapping Bands                              37904 non-null int64
# Tobacco Packaging/Wrap                       37904 non-null int64
# Other Packaging (Clean Swell)                37904 non-null int64
# Appliances (refrigerators, washers, etc.)    37904 non-null int64
# Balloons                                     37904 non-null int64
# Cigar Tips                                   37904 non-null int64
# Cigarette Lighters                           37904 non-null int64
# Construction Materials                       37904 non-null int64
# Fireworks                                    37904 non-null int64
# Tires                                        37904 non-null int64
# Toys                                         37904 non-null int64
# Other Trash (Clean Swell)                    37904 non-null int64
# Condoms                                      37904 non-null int64
# Diapers                                      37904 non-null int64
# Syringes                                     37904 non-null int64
# Tampons/Tampon Applicators                   37904 non-null int64
# Personal Hygiene (Clean Swell)               37904 non-null int64
# Foam Pieces                                  37904 non-null int64
# Glass Pieces                                 37904 non-null int64
# Plastic Pieces                               37904 non-null int64
# Total Items Collected                        37903 non-null float64
# dtypes: float64(7), int64(46), object(8)
# memory usage: 17.6+ MB
#
# Dataframe shape:  (37904, 61)
# C:\Users\solon\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\solon\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
# Cleanup ID                                                                71463
# Zone                                                Santa Clara County, CA, USA
# State                                                           California, USA
# Country                                                           United States
# GPS                                                            37.422, -122.084
# Cleanup Type                                 Land (beach, shoreline and inland)
# Cleanup Date                                                          4/22/2019
# Group Name                                                                  NaN
# Adults                                                                        1
# Children                                                                      0
# People                                                                        1
# Pounds                                                                     0.01
# Miles                                                                   2423.17
# # of bags                                                                     0
# Cigarette Butts                                                               0
# Food Wrappers (candy, chips, etc.)                                            0
# Take Out/Away Containers (Plastic)                                            0
# Take Out/Away Containers (Foam)                                               0
# Bottle Caps (Plastic)                                                         0
# Bottle Caps (Metal)                                                           0
# Lids (Plastic)                                                                0
# Straws, Stirrers                                                              0
# Forks, Knives, Spoons                                                         0
# Beverage Bottles (Plastic)                                                    0
# Beverage Bottles (Glass)                                                      0
# Beverage Cans                                                                 0
# Grocery Bags (Plastic)                                                        0
# Other Plastic Bags                                                            0
# Paper Bags                                                                    0
# Cups, Plates (Paper)                                                          0
#                                                             ...
# Cups, Plates (Foam)                                                           0
# Fishing Buoys, Pots & Traps                                                   0
# Fishing Net & Pieces                                                          0
# Fishing Line (1 yard/meter = 1 piece)                                         0
# Rope (1 yard/meter = 1 piece)                                                 0
# Fishing Gear (Clean Swell)                                                    0
# 6-Pack Holders                                                                0
# Other Plastic/Foam Packaging                                                  0
# Other Plastic Bottles (oil, bleach, etc.)                                     0
# Strapping Bands                                                               0
# Tobacco Packaging/Wrap                                                        0
# Other Packaging (Clean Swell)                                                 0
# Appliances (refrigerators, washers, etc.)                                     0
# Balloons                                                                      1
# Cigar Tips                                                                    0
# Cigarette Lighters                                                            0
# Construction Materials                                                        0
# Fireworks                                                                     0
# Tires                                                                         0
# Toys                                                                          0
# Other Trash (Clean Swell)                                                     0
# Condoms                                                                       0
# Diapers                                                                       0
# Syringes                                                                      0
# Tampons/Tampon Applicators                                                    0
# Personal Hygiene (Clean Swell)                                                0
# Foam Pieces                                                                   0
# Glass Pieces                                                                  0
# Plastic Pieces                                                                0
# Total Items Collected                                                         1
# Name: 29152, Length: 61, dtype: object

# %%
for col in df:
    print(df[col].describe(), '\n\n')
# Out:
# count     37904
# unique    37904
# top       71820
# freq          1
# Name: Cleanup ID, dtype: int64
#
#
# count                           37665
# unique                            900
# top       Los Angeles County, CA, USA
# freq                             2499
# Name: Zone, dtype: object
#
#
# count            37577
# unique              53
# top       Florida, USA
# freq             11319
# Name: State, dtype: object
#
#
# count             37903
# unique                1
# top       United States
# freq              37903
# Name: Country, dtype: object
#
#
# count                   37903
# unique                  33030
# top       27.73249, -82.74755
# freq                      218
# Name: GPS, dtype: object
#
#
# count                                  37903
# unique                                     3
# top       Land (beach, shoreline and inland)
# freq                                   37116
# Name: Cleanup Type, dtype: object
#
#
# count         37903
# unique         1730
# top       9/15/2018
# freq           3152
# Name: Cleanup Date, dtype: object
#
#
# count     26636
# unique    12973
# top       SOLVE
# freq        666
# Name: Group Name, dtype: object
#
#
# count    37903.000000
# mean        16.621481
# std        200.761902
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          6.000000
# max      22060.000000
# Name: Adults, dtype: float64
#
#
# count    37903.000000
# mean         2.452814
# std         18.684501
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       1291.000000
# Name: Children, dtype: float64
#
#
# count    37903.000000
# mean        19.074295
# std        203.218661
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          7.000000
# max      22060.000000
# Name: People, dtype: float64
#
#
# count     37903.000000
# mean        310.799010
# std        4621.795387
# min           0.000000
# 25%           1.450000
# 50%           5.600000
# 75%          24.000000
# max      425025.000000
# Name: Pounds, dtype: float64
#
#
# count    37903.000000
# mean         1.426367
# std         15.329109
# min          0.000000
# 25%          0.027500
# 50%          0.341700
# 75%          1.105100
# max       2423.166700
# Name: Miles, dtype: float64
#
#
# count    37903.000000
# mean         7.360103
# std        157.094929
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      18581.000000
# Name: # of bags, dtype: float64
#
#
# count    3.790400e+04
# mean     1.749690e+02
# std      1.704443e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      4.000000e+00
# 75%      3.000000e+01
# max      3.316012e+06
# Name: Cigarette Butts, dtype: float64
#
#
# count    3.790400e+04
# mean     6.619354e+01
# std      6.445898e+03
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      5.000000e+00
# 75%      1.900000e+01
# max      1.254500e+06
# Name: Food Wrappers (candy, chips, etc.), dtype: float64
#
#
# count     37904.000000
# mean         11.831838
# std        1153.418164
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           3.000000
# max      224237.000000
# Name: Take Out/Away Containers (Plastic), dtype: float64
#
#
# count     37904.000000
# mean          8.680614
# std         846.008907
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           2.000000
# max      164515.000000
# Name: Take Out/Away Containers (Foam), dtype: float64
#
#
# count    3.790400e+04
# mean     5.819660e+01
# std      5.667599e+03
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      4.000000e+00
# 75%      1.500000e+01
# max      1.102942e+06
# Name: Bottle Caps (Plastic), dtype: float64
#
#
# count     37904.000000
# mean         16.343394
# std        1593.613018
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max      309740.000000
# Name: Bottle Caps (Metal), dtype: float64
#
#
# count     37904.000000
# mean         14.701404
# std        1432.902698
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           4.000000
# max      278621.000000
# Name: Lids (Plastic), dtype: float64
#
#
# count     37904.000000
# mean         27.839436
# std        2712.363171
# min           0.000000
# 25%           0.000000
# 50%           2.000000
# 75%           7.000000
# max      527613.000000
# Name: Straws, Stirrers, dtype: float64
#
#
# count     37904.000000
# mean          9.548333
# std         930.114187
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           3.000000
# max      180960.000000
# Name: Forks, Knives, Spoons, dtype: float64
#
#
# count     37904.000000
# mean         42.868774
# std        4176.926612
# min           0.000000
# 25%           0.000000
# 50%           2.000000
# 75%           9.000000
# max      812449.000000
# Name: Beverage Bottles (Plastic), dtype: float64
#
#
# count     37904.000000
# mean         19.828250
# std        1931.870734
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           4.000000
# max      375785.000000
# Name: Beverage Bottles (Glass), dtype: float64
#
#
# count     37904.000000
# mean         26.371465
# std        2576.362944
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           6.000000
# max      499792.000000
# Name: Beverage Cans, dtype: float64
#
#
# count     37904.000000
# mean         18.744935
# std        1826.684840
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           5.000000
# max      355254.000000
# Name: Grocery Bags (Plastic), dtype: float64
#
#
# count     37904.000000
# mean         13.638719
# std        1329.609211
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max      258481.000000
# Name: Other Plastic Bags, dtype: float64
#
#
# count    37904.000000
# mean         5.263877
# std        513.298870
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      99761.000000
# Name: Paper Bags, dtype: float64
#
#
# count     37904.000000
# mean          6.192645
# std         603.569271
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max      117363.000000
# Name: Cups, Plates (Paper), dtype: float64
#
#
# count     37904.000000
# mean         10.982851
# std        1069.522356
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           3.000000
# max      208147.000000
# Name: Cups, Plates (Plastic), dtype: float64
#
#
# count     37904.000000
# mean          7.814954
# std         762.146261
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max      148109.000000
# Name: Cups, Plates (Foam), dtype: float64
#
#
# count    37904.000000
# mean         1.663466
# std        162.122001
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      31526.000000
# Name: Fishing Buoys, Pots & Traps, dtype: float64
#
#
# count    37904.000000
# mean         2.453303
# std        239.201670
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      46495.000000
# Name: Fishing Net & Pieces, dtype: float64
#
#
# count     37904.000000
# mean          6.233801
# std         608.075937
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max      118143.000000
# Name: Fishing Line (1 yard/meter = 1 piece), dtype: float64
#
#
# count    37904.000000
# mean         5.083685
# std        495.529874
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      96346.000000
# Name: Rope (1 yard/meter = 1 piece), dtype: float64
#
#
# count    37904.000000
# mean         2.827828
# std        275.361282
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max      53593.000000
# Name: Fishing Gear (Clean Swell), dtype: float64
#
#
# count    37904.000000
# mean         1.196655
# std        117.122059
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      22679.000000
# Name: 6-Pack Holders, dtype: float64
#
#
# count     37904.000000
# mean         14.740555
# std        1436.789967
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max      279363.000000
# Name: Other Plastic/Foam Packaging, dtype: float64
#
#
# count    37904.000000
# mean         3.764194
# std        368.395423
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      71339.000000
# Name: Other Plastic Bottles (oil, bleach, etc.), dtype: float64
#
#
# count    37904.000000
# mean         3.091969
# std        301.292197
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      58599.000000
# Name: Strapping Bands, dtype: float64
#
#
# count    37904.000000
# mean         5.039679
# std        491.336229
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      95512.000000
# Name: Tobacco Packaging/Wrap, dtype: float64
#
#
# count    37904.000000
# mean         4.846771
# std        471.883028
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          2.000000
# max      91856.000000
# Name: Other Packaging (Clean Swell), dtype: float64
#
#
# count    37904.000000
# mean         0.366030
# std         36.108204
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       6937.000000
# Name: Appliances (refrigerators, washers, etc.), dtype: float64
#
#
# count    37904.000000
# mean         4.790418
# std        466.586902
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max      90788.000000
# Name: Balloons, dtype: float64
#
#
# count     37904.000000
# mean          8.315903
# std         810.687122
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max      157603.000000
# Name: Cigar Tips, dtype: float64
#
#
# count    37904.000000
# mean         1.899588
# std        185.106841
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      36001.000000
# Name: Cigarette Lighters, dtype: float64
#
#
# count     37904.000000
# mean          7.254432
# std         707.093415
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max      137486.000000
# Name: Construction Materials, dtype: float64
#
#
# count    37904.000000
# mean         2.484065
# std        242.898922
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      47078.000000
# Name: Fireworks, dtype: float64
#
#
# count    37904.000000
# mean         2.010131
# std        197.821551
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      38096.000000
# Name: Tires, dtype: float64
#
#
# count    37904.000000
# mean         2.636133
# std        256.816764
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max      49960.000000
# Name: Toys, dtype: float64
# count     37904.000000
# mean         18.597932
# std        1810.697419
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           8.000000
# max      352468.000000
# Name: Other Trash (Clean Swell), dtype: float64
#
#
# count    37904.000000
# mean         0.808727
# std         78.887605
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      15327.000000
# Name: Condoms, dtype: float64
#
#
# count    37904.000000
# mean         0.761344
# std         74.457778
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      14429.000000
# Name: Diapers, dtype: float64
#
#
# count    37904.000000
# mean         0.598459
# std         58.585591
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      11342.000000
# Name: Syringes, dtype: float64
#
#
# count    37904.000000
# mean         1.355266
# std        132.347617
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      25685.000000
# Name: Tampons/Tampon Applicators, dtype: float64
#
#
# count    37904.000000
# mean         2.137822
# std        208.136822
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max      40516.000000
# Name: Personal Hygiene (Clean Swell), dtype: float64
#
#
# count    3.790400e+04
# mean     1.737178e+02
# std      1.719248e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      3.292299e+06
# Name: Foam Pieces, dtype: float64
#
#
# count     37904.000000
# mean         28.649694
# std        2792.134959
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max      542969.000000
# Name: Glass Pieces, dtype: float64
#
#
# count    3.790400e+04
# mean     1.579318e+02
# std      1.539350e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      8.000000e+00
# 75%      4.300000e+01
# max      2.993124e+06
# Name: Plastic Pieces, dtype: float64
#
#
# count     37903.000000
# mean        502.647284
# std        4060.754999
# min           0.000000
# 25%          19.000000
# 50%          84.000000
# 75%         264.000000
# max      440496.000000
# Name: Total Items Collected, dtype: float64

# %%
trash_types = df.loc[:, 'Cigarette Butts':'Plastic Pieces']  # isolate trash types
trash_types['Max'] = trash_types.loc[:].idxmax(axis=1)  # find most frequent trash item

cl_df = df.drop(df.loc[:,'Cigarette Butts':'Plastic Pieces'].head(0).columns, axis=1)  # separate trash classifier df
cl_df['most_freq_trash'] = trash_types['Max']

cl_df.head()
cl_df['most_freq_trash'].value_counts()
# Out:
# Cigarette Butts                              11796
# Plastic Pieces                               10307
# Food Wrappers (candy, chips, etc.)            2908
# Other Trash (Clean Swell)                     2892
# Beverage Bottles (Plastic)                    2026
# Bottle Caps (Plastic)                         1602
# Foam Pieces                                    845
# Beverage Cans                                  760
# Grocery Bags (Plastic)                         574
# Straws, Stirrers                               574
# Beverage Bottles (Glass)                       491
# Glass Pieces                                   336
# Other Packaging (Clean Swell)                  325
# Take Out/Away Containers (Plastic)             281
# Fishing Gear (Clean Swell)                     249
# Tires                                          219
# Toys                                           207
# Balloons                                       201
# Cups, Plates (Plastic)                         180
# Lids (Plastic)                                 147
# Other Plastic/Foam Packaging                   130
# Take Out/Away Containers (Foam)                126
# Fishing Line (1 yard/meter = 1 piece)          124
# Construction Materials                         120
# Forks, Knives, Spoons                          110
# Personal Hygiene (Clean Swell)                  72
# Rope (1 yard/meter = 1 piece)                   65
# Other Plastic Bags                              43
# Bottle Caps (Metal)                             33
# Cigar Tips                                      26
# Cups, Plates (Paper)                            21
# Fireworks                                       19
# Fishing Buoys, Pots & Traps                     19
# Appliances (refrigerators, washers, etc.)       14
# Fishing Net & Pieces                            13
# Cups, Plates (Foam)                             13
# Other Plastic Bottles (oil, bleach, etc.)       10
# Tampons/Tampon Applicators                       6
# Paper Bags                                       6
# Strapping Bands                                  4
# Tobacco Packaging/Wrap                           3
# Condoms                                          2
# 6-Pack Holders                                   2
# Cigarette Lighters                               1
# Syringes                                         1
# Diapers                                          1
# Name: most_freq_trash, dtype: int64

# %%
#  Used sklearn libraries

from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.compose import ColumnTransformer

# %%
# Change format of 'date' from mm/dd/yyyy to yyyy and rename to 'year' 
cl_df['Cleanup Date'] = df['Cleanup Date'].str.split('/', n = 2, expand=False)
cl_df['year'] = cl_df['Cleanup Date'].str[2].astype('int')
cl_df = cl_df[cl_df['year'] > 1990]

# Get GPS x and y
cl_df[['gps_y','gps_x']] = cl_df.GPS.str.split(expand=True)
cl_df[['gps_y']] = cl_df['gps_y'].str.slice(0, -1)
cl_df[['gps_y', 'gps_x']] = cl_df[['gps_y', 'gps_x']].astype('float')

# Change format of 'date' from mm/dd/yyyy to yyyy and rename to 'year' 
cl_df['County'] = df['Cleanup Date'].str.split(',', n = 1, expand=False)
cl_df['year'] = cl_df['Cleanup Date'].str[2].astype('int')
cl_df = cl_df[cl_df['year'] > 1990]

cat_df_list = list(df.select_dtypes(include=['object']))
num_df_list = list(df.select_dtypes(include=['float64']))

cl_df.head()
#cl_df.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-a4566d313935> in <module>
#       1 # Change format of 'date' from mm/dd/yyyy to yyyy and rename to 'year'
#       2 cl_df['Cleanup Date'] = df['Cleanup Date'].str.split('/', n = 2, expand=False)
# ----> 3 cl_df['year'] = cl_df['Cleanup Date'].str[2].astype('int')
#       4 cl_df = cl_df[cl_df['year'] > 1990]
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     532     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     533         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 534                             **kwargs)
#     535
#     536     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     631
#     632                     # _astype_nansafe works fine with 1-d only
# --> 633                     values = astype_nansafe(values.ravel(), dtype, copy=True)
#     634
#     635                 # TODO(extension)
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     681         # work around NumPy brokenness, #1987
#     682         if np.issubdtype(dtype.type, np.integer):
# --> 683             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     684
#     685         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: cannot convert float NaN to integer

# %%
# Drop poor features
cl_df.drop(['Cleanup ID', 
            'GPS',
            'Group Name'], 
             axis=1,
             inplace=True)

# %%
# test = cl_df[cl_df['Cleanup Date'].split('/') != 'Draw']
# test.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-03e0cc5339bf> in <module>
# ----> 1 test = cl_df[cl_df['Cleanup Date'].split('/') != 'Draw']
#       2 test.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
# pipeline for numerical features
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('std_scaler', StandardScaler()),
    
])

# pipeline for categorical features
cat_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('one_hot', OneHotEncoder()),
])

X_pipeline = ColumnTransformer([
    ('cat', cat_pipeline, cat_df_list),
    ('num', num_pipeline, num_df_list),
])
